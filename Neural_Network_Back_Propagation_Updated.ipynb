# %% [markdown]
# <a href="https://colab.research.google.com/github/SmrutiNIT/PythonBasics-May-29-Batch/blob/main/Neural_Network_Back_Propagation_Updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Create your first MLP in Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy

# %%
# fix random seed for reproducibility
seed = 0
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("/content/pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
# create model
model = Sequential()
model.add(Dense(12, input_dim=8,  activation='relu')) #1st layer
model.add(Dense(8,  activation='relu')) #2nd layer
model.add(Dense(1, activation='sigmoid')) #3rd layer or op layer

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Fit the model
history = model.fit(X, Y, validation_split=0.33, epochs=250, batch_size=10)
# Out:
# Epoch 1/250
# 52/52 [==============================] - 1s 5ms/step - loss: 20.6318 - accuracy: 0.3619 - val_loss: 10.3919 - val_accuracy: 0.3622
# Epoch 2/250
# 52/52 [==============================] - 0s 4ms/step - loss: 5.6938 - accuracy: 0.5058 - val_loss: 3.6271 - val_accuracy: 0.5433
# Epoch 3/250
# 52/52 [==============================] - 0s 3ms/step - loss: 2.2276 - accuracy: 0.5895 - val_loss: 1.4239 - val_accuracy: 0.5591
# Epoch 4/250
# 52/52 [==============================] - 0s 2ms/step - loss: 1.1548 - accuracy: 0.6284 - val_loss: 0.9725 - val_accuracy: 0.6378
# Epoch 5/250
# 52/52 [==============================] - 0s 2ms/step - loss: 0.9433 - accuracy: 0.6051 - val_loss: 0.8466 - val_accuracy: 0.6378
# Epoch 6/250
# 52/52 [==============================] - 0s 3ms/step - loss: 0.8659 - accuracy: 0.6070 - val_loss: 0.7968 - val_accuracy: 0.6181
# Epoch 7/250
# ...

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4985 - accuracy: 0.7591
# accuracy: 75.91%

# %%
# Visualize training history

# list all data in history
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# summarize history for accuracy
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
